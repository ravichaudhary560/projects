# %% [markdown]
# <a href="https://colab.research.google.com/github/ravichaudhary560/projects/blob/main/properdatacleannetflix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/data csv/ netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['cast'] = df["cast"].fillna("Unknown")
df['country'] = df["country"].fillna("Unknown")
df['director'] = df['director'].fillna("Unknown")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
a = df[df['rating'].isnull()]

# %%
a
# Out:
#      show_id     type                                              title  \
# 5989   s5990    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 6827   s6828  TV Show                  Gargantia on the Verdurous Planet
# 7312   s7313  TV Show                                       Little Lunch
# 7537   s7538    Movie                               My Honor Was Loyalty
#
#              director                                               cast  \
# 5989          Unknown                        Oprah Winfrey, Ava DuVernay
# 6827          Unknown  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# 7312          Unknown  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# 7537  Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#         country        date_added  release_year rating  duration  \
# 5989    Unknown  January 26, 2017          2017    NaN    37 min
# 6827      Japan  December 1, 2016          2013    NaN  1 Season
# ...

# %%
a.loc[a.index[0],"rating"] = "PG-13"
a.loc[a.index[1],"rating"] = "TV-MA"
a.loc[a.index[2],"rating"] = "TV-Y7"
a.loc[a.index[3],"rating"] = "TV-14"

# %%
b=df[df['date_added'].isnull()]

# %%
b
# Out:
#      show_id     type                                        title director  \
# 6066   s6067  TV Show  A Young Doctor's Notebook and Other Stories  Unknown
# 6174   s6175  TV Show              Anthony Bourdain: Parts Unknown  Unknown
# 6795   s6796  TV Show                                      Frasier  Unknown
# 6806   s6807  TV Show                                      Friends  Unknown
# 6901   s6902  TV Show                              Gunslinger Girl  Unknown
# 7196   s7197  TV Show                                     Kikoriki  Unknown
# 7254   s7255  TV Show                          La Familia P. Luche  Unknown
# 7406   s7407  TV Show                                        Maron  Unknown
# 7847   s7848  TV Show                                 Red vs. Blue  Unknown
# 8182   s8183  TV Show                 The Adventures of Figaro Pho  Unknown
#
#                                                    cast         country  \
# ...

# %%
b.loc[b.index[0],"date_added"] = "September 25, 2021"
b.loc[b.index[1],'date_added'] = "September 25, 2021"
b.loc[b.index[2],'date_added'] = "September 25, 2021"
b.loc[b.index[3],'date_added'] = "September 25, 2021"
b.loc[b.index[4],"date_added"] = "September 25, 2021"
b.loc[b.index[5],"date_added"] = "September 25, 2021"
b.loc[b.index[6],'date_added'] = "September 25, 2021"
b.loc[b.index[7],"date_added"] = "September 25, 2021"
b.loc[b.index[8],"date_added"] = "September 25, 2021"
b.loc[b.index[9],"date_added"] = "September 25, 2021"

# %%
c= df[df['duration'].isnull()]

# %%
c
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description
# 5541      NaN    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794      NaN    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813      NaN    Movies  The comic puts his trademark hilarious/thought...

# %%
c.loc[c.index[0],"duration"] = "74 min"
c.loc[c.index[1],"duration"] = "84 min"
c.loc[c.index[2],"duration"] = "66 min"


c.loc[c.index[0],"rating"] = "PG"
c.loc[c.index[1],"rating"] = "R"
c.loc[c.index[2],"rating"] = "R"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
c = c.set_index("show_id")

# %%
b = b.set_index("show_id")

# %%
a = a.set_index("show_id")

# %%
df = df.set_index("show_id")

# %%
df.update(a)
df.update(b)
df.update(c)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, s1 to s8807
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      8807 non-null   object
#  3   cast          8807 non-null   object
#  4   country       8807 non-null   object
#  5   date_added    8807 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8807 non-null   object
#  8   duration      8807 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 825.7+ KB

# %%
df["genres"] = df['listed_in'].str.split(',').str[0]

# %%
df = df.reset_index()

# %%
df['year'] = pd.to_datetime(df['release_year'],errors="coerce",format="%Y").dt.year

# %%
df['time'] = pd.to_numeric(df['duration'].str.extract("(\d+)",expand=False),errors='coerce')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.genres.nunique()
# Out:
# 36

# %%
genres = df.groupby('genres').size().reset_index()

# %%
genres.rename(columns={0:"Count"},inplace=True)

# %%
import plotly.express as px

# %%
fig = px.bar(genres,x="genres",y="Count",title="Distribution of Genres",labels={"genres":"Genres"})

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
release = df.groupby("release_year").size().reset_index(name="Count")

# %%
px.bar(release,x='release_year',y='Count',title="Distribution of Release_Year",labels={'release_year':'Year','Count':'No. of Titles'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['country'] = df['country'].str.split(',').str[0]

# %%
country = df.groupby('country').size().reset_index()

# %%
df[df.country.duplicated()]
# Out:
#       level_0  index show_id     type                             title  \
# 3           3      3      s4  TV Show             Jailbirds New Orleans
# 5           5      5      s6  TV Show                     Midnight Mass
# 6           6      6      s7    Movie  My Little Pony: A New Generation
# 7           7      7      s8    Movie                           Sankofa
# 9           9      9     s10    Movie                      The Starling
# ...       ...    ...     ...      ...                               ...
# 8798     8800   8802   s8803    Movie                            Zodiac
# 8799     8801   8803   s8804  TV Show                       Zombie Dumb
# 8800     8802   8804   s8805    Movie                        Zombieland
# 8801     8803   8805   s8806    Movie                              Zoom
# 8802     8804   8806   s8807    Movie                            Zubaan
#
#                            director  \
# 3                           Unknown
# ...

# %%
df.country.nunique()
# Out:
# 86

# %%
country = country.rename(columns={0:"Count"})

# %%
country
# Out:
#          country  Count
# 0      Argentina     76
# 1      Australia    117
# 2        Austria      9
# 3     Bangladesh      3
# 4        Belarus      1
# ..           ...    ...
# 81       Uruguay      9
# 82     Venezuela      2
# 83       Vietnam      7
# 84  West Germany      1
# 85      Zimbabwe      1
#
# [86 rows x 2 columns]

# %%
df[(df['country'] == "")]
# Out:
# Empty DataFrame
# Columns: [level_0, index, show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, genres, year, time]
# Index: []

# %%
df.drop([193,365],axis=0,inplace=True)

# %%
import plotly.express as px
px.choropleth(country,locations=country['country'],locationmode='country names',projection='orthographic',color=country['Count'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df
# Out:
#       level_0  index show_id     type                  title         director  \
# 0           0      0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      1      s2  TV Show          Blood & Water          Unknown
# 2           2      2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4           4      4      s5  TV Show           Kota Factory          Unknown
# ...       ...    ...     ...      ...                    ...              ...
# 8798     8800   8802   s8803    Movie                 Zodiac    David Fincher
# 8799     8801   8803   s8804  TV Show            Zombie Dumb          Unknown
# 8800     8802   8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8801     8803   8805   s8806    Movie                   Zoom     Peter Hewitt
# 8802     8804   8806   s8807    Movie                 Zubaan      Mozez Singh
#
# ...

# %%
df['date_month'] = pd.to_datetime(df['date_added'], errors='coerce', format='mixed').dt.month

# %%
a=df.groupby(['year','date_month']).size().reset_index(name='count')

# %%
px.line(a,x='year',y='count',color='date_month')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
a=df.groupby('rating').size().reset_index(name='count')

# %%
px.bar(a,x='rating',y='count',color='count')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df
# Out:
#       level_0  index show_id     type                  title         director  \
# 0           0      0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      1      s2  TV Show          Blood & Water          Unknown
# 2           2      2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4           4      4      s5  TV Show           Kota Factory          Unknown
# ...       ...    ...     ...      ...                    ...              ...
# 8798     8800   8802   s8803    Movie                 Zodiac    David Fincher
# 8799     8801   8803   s8804  TV Show            Zombie Dumb          Unknown
# 8800     8802   8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8801     8803   8805   s8806    Movie                   Zoom     Peter Hewitt
# 8802     8804   8806   s8807    Movie                 Zubaan      Mozez Singh
#
# ...

# %%
a = df[df['type'] == "Movie"]

# %%
b = df[df['type'] == "TV Show"]

# %%
a=df.groupby(['type','time']).size().reset_index(name="count")

# %%
px.bar(a,x='type',y='count',color='time',barmode='overlay')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
a=df.groupby(['type','rating']).size().reset_index(name='count').sort_values(by='count',ascending=False)

# %%
px.bar(a,x='rating',y='count',color='type')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
a = df['time'].describe()

# %%
px.histogram(a,x='time')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
